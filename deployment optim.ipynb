# %%
import sys 
import os
sys.path.append(os.path.abspath("/Users/mouginot/work/helpmetric"))
import cymetrichelper as cyh
import pandahelper as pdh


import cymetric as cym
import pandas as pd

import matplotlib.pyplot as plt
from cymetric import graphs as cgr
from cymetric import timeseries as tm

# %matplotlib inline

# %%
def month2year(df, mode=0, division=12):
    dfn = pd.DataFrame(columns=['Time','Mass'])
    df.rename(index=str, columns={"Quantity": "Mass"})
    val = 0
    for index, row in df.iterrows():
        if mode == 0:
            val = row['Mass']
        else:
            val += row['Mass']
        if row['Time'] % division == 0:
            if mode == 2:
                val *= 1./float(division)
            dfn.loc[int(row['Time'] / division)] = int(row['Time'] / 12)
            dfn.loc[int(row['Time'] / division)]['Mass'] = val
            #val = 0
    return dfn
            
    
    
def maxperdiv(df, division=12):
    dfn = pd.DataFrame(columns=['Time','Mass'])
    val = 0
    for index, row in df.iterrows():
        if val < row['Mass']:
            val = row['Mass']
        if row['Time'] % division == 0:
            dfn.loc[int(row['Time'] / division)] = int(row['Time'] / 12)
            dfn.loc[int(row['Time'] / division)]['Mass'] = val
            val = 0
    return dfn

def increaseonly(df):
    dfn = pd.DataFrame(columns=['Time','Mass'])
    val = 0
    for index, row in df.iterrows():
        if val < row['Mass']:
            val = row['Mass']
            dfn.loc[int(row['Time'])] = int(row['Time'])
            dfn.loc[int(row['Time'])]['Mass'] = row['Mass']
            val = row['Mass']
    return dfn

# %%
db = cym.dbopen("ref.h5")
ev = cym.Evaluator(db=db, write=False)

fac = ['sfr']
nucs = ['238pu', '239pu', '240pu', '241pu', '242pu']
coms = ()



df1 = tm.transactions(ev, receivers=fac, nucs=nucs)
df2 = tm.inventories(ev, facilities=['str_fuel'], nucs=nucs)


df1.columns = ['Time', 'Mass']
df2.columns = ['Time', 'Mass']




df1_y = month2year(df1,1,12)
df2_y = month2year(df2,0,12)
df1_y['Mass2'] = df2_y['Mass']

#ax = df1_y.plot('Time','Mass',linestyle='', marker='+', markersize='20' ,figsize = (20,12))
# Major ticks every 20, minor ticks every 5
print("time", "UsedPu", "SpentPu")
for index, row in df1_y.iterrows():
   print(row['Time'], row['Mass'], row['Mass2'])
# Out:
# time UsedPu SpentPu
# 0 0.0 0.0
# 1 8231.198148363894 0.0
# 2 8231.198148363894 0.0
# 3 8231.198148363894 0.0
# 4 8231.198148363894 0.0
# 5 8231.198148363894 0.0
# 6 8231.198148363894 0.0
# 7 16402.531653832782 8565.4984713093
# 8 16402.531653832782 8551.643060528068
# 9 16402.531653832782 8536.907650976118
# 10 16402.531653832782 8522.51597519442
# 11 16402.531653832782 8508.701420871803
# 12 16402.531653832782 8495.48943990971
# 13 24494.721307703523 17048.957054015897
# 14 24494.721307703523 17024.948778569127
# 15 24494.721307703523 16999.1492765229
# 16 24494.721307703523 16973.892444956648
# 17 24494.721307703523 16949.62763590104
# 18 24494.721307703523 16926.40832062945
# 19 24494.721307703523 16904.206338355343
# 20 32560.390677431147 25436.769959534166
# 21 32560.390677431147 25403.12891279743
# 22 32560.390677431147 25369.80860473484
# 23 32560.390677431147 25337.704207488852
# 24 32560.390677431147 25306.95059948149
# 25 32560.390677431147 25277.524680951192
# ...

# %%
db = cym.dbopen("fix_1.h5")
ev = cym.Evaluator(db=db, write=False)

fac = ['sfr']
nucs = ['238pu', '239pu', '240pu', '241pu', '242pu']
coms = ()



df1 = tm.transactions(ev, receivers=fac, nucs=nucs)
df2 = tm.inventories(ev, facilities=['str_fuel'], nucs=nucs)


df1.columns = ['Time', 'Mass']
df2.columns = ['Time', 'Mass']




df1_y = month2year(df1,1,12)
df2_y = month2year(df2,0,12)
df1_y['Mass2'] = df2_y['Mass']

#ax = df1_y.plot('Time','Mass',linestyle='', marker='+', markersize='20' ,figsize = (20,12))
# Major ticks every 20, minor ticks every 5
print("time", "UsedPu", "SpentPu")
for index, row in df1_y.iterrows():
   print(row['Time'], row['Mass'], row['Mass2'])
# Out:
# time UsedPu SpentPu
# 0 0.0 0.0
# 1 8190.769470637821 0.0
# 2 8190.769470637821 0.0
# 3 8190.769470637821 0.0
# 4 8190.769470637821 0.0
# 5 8190.769470637821 0.0
# 6 8190.769470637821 0.0
# 7 16111.629515211844 8268.211119521733
# 8 16111.629515211844 8254.620878287142
# 9 16111.629515211844 8237.925869689043
# 10 16111.629515211844 8221.168178391008
# 11 16111.629515211844 8204.962299982268
# 12 16111.629515211844 8189.411444050616
# 13 23680.703784758647 16436.79841340807
# 14 23680.703784758647 16415.765792072765
# 15 23680.703784758647 16387.865635900147
# 16 23680.703784758647 16359.496684214659
# 17 23680.703784758647 16331.964097590106
# 18 23680.703784758647 16305.499657353996
# 19 23680.703784758647 16280.110571742653
# 20 31134.616576946166 24506.72601755679
# 21 31134.616576946166 24473.238606514482
# 22 31134.616576946166 24437.699887425806
# 23 31134.616576946166 24402.87238958441
# 24 31134.616576946166 24369.286060723076
# 25 31134.616576946166 24337.001953176794
# ...

# %%
db = cym.dbopen("fix_2.h5")
ev = cym.Evaluator(db=db, write=False)

fac = ['sfr']
nucs = ['238pu', '239pu', '240pu', '241pu', '242pu']
coms = ()



df1 = tm.transactions(ev, receivers=fac, nucs=nucs)
df2 = tm.inventories(ev, facilities=['str_fuel'], nucs=nucs)


df1.columns = ['Time', 'Mass']
df2.columns = ['Time', 'Mass']




df1_y = month2year(df1,1,12)
df2_y = month2year(df2,0,12)
df1_y['Mass2'] = df2_y['Mass']

#ax = df1_y.plot('Time','Mass',linestyle='', marker='+', markersize='20' ,figsize = (20,12))
# Major ticks every 20, minor ticks every 5
print("time", "UsedPu", "SpentPu")
for index, row in df1_y.iterrows():
   print(row['Time'], row['Mass'], row['Mass2'])
# Out:
# time UsedPu SpentPu
# 0 0.0 0.0
# 1 8229.557237966988 0.0
# 2 8229.557237966988 0.0
# 3 8229.557237966988 0.0
# 4 8229.557237966988 0.0
# 5 8229.557237966988 0.0
# 6 8229.557237966988 0.0
# 7 16344.551578502078 8742.306519704283
# 8 16344.551578502078 8728.403750704214
# 9 16344.551578502078 8713.15747936203
# 10 16344.551578502078 8698.164049705869
# 11 16344.551578502078 8683.735072981448
# 12 16344.551578502078 8669.912094111003
# 13 24304.57289410151 17395.55561087661
# 14 24304.57289410151 17371.89994404466
# 15 24304.57289410151 17345.393642719864
# 16 24304.57289410151 17319.208994827713
# 17 24304.57289410151 17293.972059631822
# 18 24304.57289410151 17269.77332899413
# 19 24304.57289410151 17246.592199168077
# 20 32211.010653635043 25945.07095583064
# 21 32211.010653635043 25910.997460597468
# 22 32211.010653635043 25876.737308437576
# 23 32211.010653635043 25843.573970699632
# 24 32211.010653635043 25811.72467196578
# 25 32211.010653635043 25781.184062445594
# ...

# %%
db = cym.dbopen("fix_3.h5")
ev = cym.Evaluator(db=db, write=False)

fac = ['sfr']
nucs = ['238pu', '239pu', '240pu', '241pu', '242pu']
coms = ()



df1 = tm.transactions(ev, receivers=fac, nucs=nucs)
df2 = tm.inventories(ev, facilities=['str_fuel'], nucs=nucs)


df1.columns = ['Time', 'Mass']
df2.columns = ['Time', 'Mass']




df1_y = month2year(df1,1,12)
df2_y = month2year(df2,0,12)
df1_y['Mass2'] = df2_y['Mass']

#ax = df1_y.plot('Time','Mass',linestyle='', marker='+', markersize='20' ,figsize = (20,12))
# Major ticks every 20, minor ticks every 5
print("time", "UsedPu", "SpentPu")
for index, row in df1_y.iterrows():
   print(row['Time'], row['Mass'], row['Mass2'])
# Out:
# time UsedPu SpentPu
# 0 0.0 0.0
# 1 8224.103216909132 0.0
# 2 8224.103216909132 0.0
# 3 8224.103216909132 0.0
# 4 8224.103216909132 0.0
# 5 8224.103216909132 0.0
# 6 8224.103216909132 0.0
# 7 16166.306402137638 8306.651659366873
# 8 16166.306402137638 8292.623243041944
# 9 16166.306402137638 8275.635560785864
# 10 16166.306402137638 8258.620627749136
# 11 16166.306402137638 8242.169478403195
# 12 16166.306402137638 8226.38016110877
# 13 23739.565745300064 16511.156493263174
# 14 23739.565745300064 16489.458383244695
# 15 23739.565745300064 16461.079454655985
# 16 23739.565745300064 16432.277821374304
# 17 23739.565745300064 16404.328645711277
# 18 23739.565745300064 16377.457087647781
# 19 23739.565745300064 16351.66868610476
# 20 31191.293983595006 24613.278856289144
# 21 31191.293983595006 24579.210491214533
# 22 31191.293983595006 24543.138290523064
# 23 31191.293983595006 24507.79329820295
# 24 31191.293983595006 24473.698554397106
# 25 31191.293983595006 24440.91340897866
# ...

# %%
db = cym.dbopen("model_1.h5")
ev = cym.Evaluator(db=db, write=False)

fac = ['sfr']
nucs = ['238pu', '239pu', '240pu', '241pu', '242pu']
coms = ()



df1 = tm.transactions(ev, receivers=fac, nucs=nucs)
df2 = tm.inventories(ev, facilities=['str_fuel'], nucs=nucs)


df1.columns = ['Time', 'Mass']
df2.columns = ['Time', 'Mass']




df1_y = month2year(df1,1,12)
df2_y = month2year(df2,0,12)
df1_y['Mass2'] = df2_y['Mass']

#ax = df1_y.plot('Time','Mass',linestyle='', marker='+', markersize='20' ,figsize = (20,12))
# Major ticks every 20, minor ticks every 5
print("time", "UsedPu", "SpentPu")
for index, row in df1_y.iterrows():
   print(row['Time'], row['Mass'], row['Mass2'])
# Out:
# time UsedPu SpentPu
# 0 0.0 0.0
# 1 8024.204777658792 0.0
# 2 8024.204777658792 0.0
# 3 8024.204777658792 0.0
# 4 8024.204777658792 0.0
# 5 8024.204777658792 0.0
# 6 8024.204777658792 0.0
# 7 15936.704245661102 8640.461645850293
# 8 15936.704245661102 8626.836734813194
# 9 15936.704245661102 8611.900342915746
# 10 15936.704245661102 8597.213029064711
# 11 15936.704245661102 8583.079337806314
# 12 15936.704245661102 8569.539788408483
# 13 23698.096660602234 17194.40092108539
# 14 23698.096660602234 17171.200389828475
# 15 23698.096660602234 17145.2205140213
# 16 23698.096660602234 17119.55967940481
# 17 23698.096660602234 17094.82915958352
# 18 23698.096660602234 17071.117105133824
# 19 23698.096660602234 17048.403161915037
# 20 31407.241359026386 25647.577452904516
# 21 31407.241359026386 25614.15604804428
# 22 31407.241359026386 25580.560936795548
# 23 31407.241359026386 25548.04438590232
# 24 31407.241359026386 25516.818000190855
# 25 31407.241359026386 25486.87616685826
# ...

# %%
db = cym.dbopen("model_2.h5")
ev = cym.Evaluator(db=db, write=False)

fac = ['sfr']
nucs = ['238pu', '239pu', '240pu', '241pu', '242pu']
coms = ()



df1 = tm.transactions(ev, receivers=fac, nucs=nucs)
df2 = tm.inventories(ev, facilities=['str_fuel'], nucs=nucs)


df1.columns = ['Time', 'Mass']
df2.columns = ['Time', 'Mass']




df1_y = month2year(df1,1,12)
df2_y = month2year(df2,0,12)
df1_y['Mass2'] = df2_y['Mass']

#ax = df1_y.plot('Time','Mass',linestyle='', marker='+', markersize='20' ,figsize = (20,12))
# Major ticks every 20, minor ticks every 5
print("time", "UsedPu", "SpentPu")
for index, row in df1_y.iterrows():
   print(row['Time'], row['Mass'], row['Mass2'])
# Out:
# time UsedPu SpentPu
# 0 0.0 0.0
# 1 11657.011008876787 0.0
# 2 11657.011008876787 0.0
# 3 11657.011008876787 0.0
# 4 11657.011008876787 0.0
# 5 11657.011008876787 0.0
# 6 11657.011008876787 0.0
# 7 23151.772433295657 10643.328553180598
# 8 23151.772433295657 10624.71923765093
# 9 23151.772433295657 10604.316425097646
# 10 23151.772433295657 10584.243263458666
# 11 23151.772433295657 10564.914658551766
# 12 23151.772433295657 10546.386395658072
# 13 34427.04369381507 21150.497378965825
# 14 34427.04369381507 21119.187269629252
# 15 34427.04369381507 21083.99177708361
# 16 34427.04369381507 21049.184782706234
# 17 34427.04369381507 21015.611812518575
# 18 34427.04369381507 20983.397172983092
# 19 34427.04369381507 20952.51546149203
# 20 45626.43817531415 31498.334824446156
# 21 45626.43817531415 31453.61219026919
# 22 45626.43817531415 31408.53044869237
# 23 45626.43817531415 31364.843023546848
# 24 45626.43817531415 31322.851077639505
# 25 45626.43817531415 31282.552407069023
# ...

# %%
db = cym.dbopen("model_3.h5")
ev = cym.Evaluator(db=db, write=False)

fac = ['sfr']
nucs = ['238pu', '239pu', '240pu', '241pu', '242pu']
coms = ()



df1 = tm.transactions(ev, receivers=fac, nucs=nucs)
df2 = tm.inventories(ev, facilities=['str_fuel'], nucs=nucs)


df1.columns = ['Time', 'Mass']
df2.columns = ['Time', 'Mass']




df1_y = month2year(df1,1,12)
df2_y = month2year(df2,0,12)
df1_y['Mass2'] = df2_y['Mass']

#ax = df1_y.plot('Time','Mass',linestyle='', marker='+', markersize='20' ,figsize = (20,12))
# Major ticks every 20, minor ticks every 5
print("time", "UsedPu", "SpentPu")
for index, row in df1_y.iterrows():
   print(row['Time'], row['Mass'], row['Mass2'])
# Out:
# time UsedPu SpentPu
# 0 0.0 0.0
# 1 8432.924390088583 0.0
# 2 8432.924390088583 0.0
# 3 8432.924390088583 0.0
# 4 8432.924390088583 0.0
# 5 8432.924390088583 0.0
# 6 8432.924390088583 0.0
# 7 16576.79215566325 8404.038161727338
# 8 16576.79215566325 8389.639235196571
# 9 16576.79215566325 8372.205973600687
# 10 16576.79215566325 8354.745071744645
# 11 16576.79215566325 8337.862616778206
# 12 16576.79215566325 8321.65915266543
# 13 24342.349621762456 16701.288837993452
# 14 24342.349621762456 16679.059272690727
# 15 24342.349621762456 16649.973777000178
# 16 24342.349621762456 16620.4528609211
# 17 24342.349621762456 16591.804859839194
# 18 24342.349621762456 16564.26087248798
# 19 24342.349621762456 16537.826675886485
# 20 31983.287955568674 24891.286739445077
# 21 31983.287955568674 24856.437721530947
# 22 31983.287955568674 24819.526340876455
# 23 31983.287955568674 24783.355922003728
# 24 31983.287955568674 24748.46357492352
# 25 31983.287955568674 24714.910483611493
# ...
